# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn import preprocessing
import matplotlib.pyplot as plt

# %%
# import dataset
data=pd.read_csv("/Users/beckybian/Desktop/NYUstudy/大三下/Intro to DS/Final project/movieReplicationSet - Copy.csv")

# %%
data
# Out:
#       The Life of David Gale (2003)  Wing Commander (1999)  \
# 0                               NaN                    NaN
# 1                               NaN                    NaN
# 2                               NaN                    NaN
# 3                               NaN                    NaN
# 4                               NaN                    NaN
# ...                             ...                    ...
# 1092                            NaN                    NaN
# 1093                            3.0                    4.0
# 1094                            NaN                    NaN
# 1095                            NaN                    NaN
# 1096                            NaN                    NaN
#
#       Django Unchained (2012)  Alien (1979)  \
# 0                         4.0           NaN
# 1                         1.5           NaN
# 2                         NaN           NaN
# 3                         2.0           NaN
# 4                         3.5           NaN
# ...                       ...           ...
# 1092                      NaN           NaN
# 1093                      NaN           NaN
# 1094                      NaN           NaN
# 1095                      NaN           NaN
# 1096                      4.0           NaN
#
#       Indiana Jones and the Last Crusade (1989)  Snatch (2000)  \
# 0                                           3.0            NaN
# 1                                           NaN            NaN
# 2                                           NaN            NaN
# 3                                           3.0            NaN
# 4                                           0.5            NaN
# ...                                         ...            ...
# 1092                                        3.5            NaN
# 1093                                        4.0            4.0
# 1094                                        NaN            NaN
# 1095                                        NaN            NaN
# 1096                                        2.5            NaN
#
#       Rambo: First Blood Part II (1985)  Fargo (1996)  \
# 0                                   NaN           NaN
# 1                                   NaN           NaN
# 2                                   NaN           NaN
# 3                                   NaN           NaN
# 4                                   0.5           1.0
# ...                                 ...           ...
# 1092                                NaN           NaN
# 1093                                2.5           NaN
# 1094                                NaN           3.5
# 1095                                NaN           NaN
# 1096                                NaN           3.0
#
#       Let the Right One In (2008)  Black Swan (2010)  ...  \
# 0                             NaN                NaN  ...
# 1                             NaN                NaN  ...
# 2                             NaN                NaN  ...
# 3                             NaN                4.0  ...
# 4                             NaN                0.0  ...
# ...                           ...                ...  ...
# 1092                          NaN                NaN  ...
# 1093                          3.5                3.5  ...
# 1094                          NaN                NaN  ...
# 1095                          NaN                NaN  ...
# 1096                          NaN                3.5  ...
#
#       When watching a movie I cheer or shout or talk or curse at the screen  \
# 0                                                   1.0
# 1                                                   3.0
# 2                                                   5.0
# 3                                                   3.0
# 4                                                   2.0
# ...                                                 ...
# 1092                                                3.0
# 1093                                                5.0
# 1094                                                6.0
# 1095                                                1.0
# 1096                                                3.0
#
#       When watching a movie I feel like the things on the screen are happening to me  \
# 0                                                   6.0
# 1                                                   1.0
# 2                                                   4.0
# 3                                                   1.0
# 4                                                   3.0
# ...                                                 ...
# 1092                                                4.0
# 1093                                                3.0
# 1094                                                3.0
# 1095                                                1.0
# 1096                                                4.0
#
#       As a movie unfolds I start to have problems keeping track of events that happened earlier  \
# 0                                                   2.0
# 1                                                   1.0
# 2                                                   3.0
# 3                                                   1.0
# 4                                                   2.0
# ...                                                 ...
# 1092                                                3.0
# 1093                                                5.0
# 1094                                                1.0
# 1095                                                1.0
# 1096                                                1.0
#
#       The emotions on the screen "rub off" on me - for instance if something sad is happening I get sad or if something frightening is happening I get scared  \
# 0                                                   5.0
# 1                                                   6.0
# 2                                                   5.0
# 3                                                   4.0
# 4                                                   5.0
# ...                                                 ...
# 1092                                                5.0
# 1093                                                5.0
# 1094                                                6.0
# 1095                                                4.0
# 1096                                                4.0
#
#       When watching a movie I get completely immersed in the alternative reality of the film  \
# 0                                                   5.0
# 1                                                   5.0
# 2                                                   5.0
# 3                                                   5.0
# 4                                                   6.0
# ...                                                 ...
# 1092                                                5.0
# 1093                                                5.0
# 1094                                                6.0
# 1095                                                3.0
# 1096                                                4.0
#
#       Movies change my position on social economic or political issues  \
# 0                                                   5.0
# 1                                                   3.0
# 2                                                   4.0
# 3                                                   3.0
# 4                                                   4.0
# ...                                                 ...
# 1092                                                4.0
# 1093                                                6.0
# 1094                                                4.0
# 1095                                                3.0
# 1096                                                4.0
#
#       When watching movies things get so intense that I have to stop watching  \
# 0                                                   1.0
# 1                                                   2.0
# 2                                                   4.0
# 3                                                   1.0
# 4                                                   4.0
# ...                                                 ...
# 1092                                                4.0
# 1093                                                5.0
# 1094                                                2.0
# 1095                                                1.0
# 1096                                                1.0
#
#       Gender identity (1 = female; 2 = male; 3 = self-described)  \
# 0                                                   1.0
# 1                                                   1.0
# 2                                                   1.0
# 3                                                   1.0
# 4                                                   1.0
# ...                                                 ...
# 1092                                                1.0
# 1093                                                1.0
# 1094                                                1.0
# 1095                                                1.0
# 1096                                                1.0
#
#       Are you an only child? (1: Yes; 0: No; -1: Did not respond)  \
# 0                                                     0
# 1                                                     0
# 2                                                     1
# 3                                                     0
# 4                                                     1
# ...                                                 ...
# 1092                                                  0
# 1093                                                  0
# 1094                                                  0
# 1095                                                  0
# 1096                                                  0
#
#       Movies are best enjoyed alone (1: Yes; 0: No; -1: Did not respond)
# 0                                                     1
# 1                                                     0
# 2                                                     0
# 3                                                     1
# 4                                                     1
# ...                                                 ...
# 1092                                                  0
# 1093                                                  0
# 1094                                                  0
# 1095                                                  1
# 1096                                                  1
#
# [1097 rows x 477 columns]

# %%
# standardize the dataset
min_max = preprocessing.MinMaxScaler()
mt = min_max.fit_transform(data.iloc[:,0:400].values)
mt=pd.DataFrame(mt,columns=data.iloc[:,0:400].columns)

# %%
mt
# Out:
#       The Life of David Gale (2003)  Wing Commander (1999)  \
# 0                               NaN                    NaN
# 1                               NaN                    NaN
# 2                               NaN                    NaN
# 3                               NaN                    NaN
# 4                               NaN                    NaN
# ...                             ...                    ...
# 1092                            NaN                    NaN
# 1093                           0.75                    1.0
# 1094                            NaN                    NaN
# 1095                            NaN                    NaN
# 1096                            NaN                    NaN
#
#       Django Unchained (2012)  Alien (1979)  \
# 0                       1.000           NaN
# 1                       0.375           NaN
# 2                         NaN           NaN
# 3                       0.500           NaN
# 4                       0.875           NaN
# ...                       ...           ...
# 1092                      NaN           NaN
# 1093                      NaN           NaN
# 1094                      NaN           NaN
# 1095                      NaN           NaN
# 1096                    1.000           NaN
#
#       Indiana Jones and the Last Crusade (1989)  Snatch (2000)  \
# 0                                         0.750            NaN
# 1                                           NaN            NaN
# 2                                           NaN            NaN
# 3                                         0.750            NaN
# 4                                         0.125            NaN
# ...                                         ...            ...
# 1092                                      0.875            NaN
# 1093                                      1.000            1.0
# 1094                                        NaN            NaN
# 1095                                        NaN            NaN
# 1096                                      0.625            NaN
#
#       Rambo: First Blood Part II (1985)  Fargo (1996)  \
# 0                                   NaN           NaN
# 1                                   NaN           NaN
# 2                                   NaN           NaN
# 3                                   NaN           NaN
# 4                                 0.125         0.250
# ...                                 ...           ...
# 1092                                NaN           NaN
# 1093                              0.625           NaN
# 1094                                NaN         0.875
# 1095                                NaN           NaN
# 1096                                NaN         0.750
#
#       Let the Right One In (2008)  Black Swan (2010)  ...  X-Men 2 (2003)  \
# 0                             NaN                NaN  ...             NaN
# 1                             NaN                NaN  ...             NaN
# 2                             NaN                NaN  ...             NaN
# 3                             NaN              1.000  ...             NaN
# 4                             NaN              0.000  ...           0.625
# ...                           ...                ...  ...             ...
# 1092                          NaN                NaN  ...             NaN
# 1093                        0.875              0.875  ...           1.000
# 1094                          NaN                NaN  ...             NaN
# 1095                          NaN                NaN  ...             NaN
# 1096                          NaN              0.875  ...             NaN
#
#       The Usual Suspects (1995)  The Mask (1994)  Jaws (1975)  \
# 0                           NaN              NaN        1.000
# 1                           NaN              NaN          NaN
# 2                           NaN              NaN          NaN
# 3                          0.75              NaN          NaN
# 4                           NaN             0.75          NaN
# ...                         ...              ...          ...
# 1092                        NaN              NaN          NaN
# 1093                        NaN             1.00        0.875
# 1094                        NaN              NaN          NaN
# 1095                        NaN              NaN          NaN
# 1096                        NaN              NaN        0.875
#
#       Harry Potter and the Chamber of Secrets (2002)  Patton (1970)  \
# 0                                              0.125            NaN
# 1                                              1.000            NaN
# 2                                              0.875            NaN
# 3                                              0.625            NaN
# 4                                                NaN            NaN
# ...                                              ...            ...
# 1092                                           1.000            NaN
# 1093                                           0.875            1.0
# 1094                                           1.000            NaN
# 1095                                           0.625            NaN
# 1096                                           1.000            NaN
#
#       Anaconda (1997)  Twister (1996)  MacArthur (1977)  \
# 0                 NaN             NaN               NaN
# 1                 NaN             NaN               NaN
# 2                 NaN             NaN               NaN
# 3                 NaN             NaN               NaN
# 4                 NaN           0.375               NaN
# ...               ...             ...               ...
# 1092              NaN             NaN               NaN
# 1093            0.875           1.000               1.0
# 1094              NaN             NaN               NaN
# 1095              NaN             NaN               NaN
# 1096              NaN             NaN               NaN
#
#       Look Who's Talking (1989)
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 1092                        NaN
# 1093                        1.0
# 1094                        NaN
# 1095                        NaN
# 1096                        NaN
#
# [1097 rows x 400 columns]

# %% [markdown]
# # Conduct PCA for Sensation Seeking

# %%
# conduct PCA for personality variables
ss=data.iloc[:,400:420]

# %%
ss1=data.iloc[:,400:420]

# %%
ss
# Out:
#       I enjoy driving fast  I enjoy rollercoasters   \
# 0                      5.0                      5.0
# 1                      4.0                      5.0
# 2                      4.0                      4.0
# 3                      5.0                      5.0
# 4                      4.0                      1.0
# ...                    ...                      ...
# 1092                   2.0                      4.0
# 1093                   3.0                      5.0
# 1094                   4.0                      5.0
# 1095                   3.0                      4.0
# 1096                   5.0                      5.0
#
#       Have you ever bungee-jumped?  I enjoy impulse shopping  \
# 0                              2.0                       5.0
# 1                              2.0                       4.0
# 2                              1.0                       2.0
# 3                              2.0                       5.0
# 4                              3.0                       3.0
# ...                            ...                       ...
# 1092                           2.0                       5.0
# 1093                           2.0                       5.0
# 1094                           2.0                       2.0
# 1095                           2.0                       5.0
# 1096                           1.0                       5.0
#
#       I sometimes go out on weeknights even if I have work to do  \
# 0                                                   1.0
# 1                                                   2.0
# 2                                                   2.0
# 3                                                
# 1095                             1.0
# 1096                             1.0
#
# [1097 rows x 20 columns]

# %%
# deal with null values
ss.isnull().sum()
# Out:
# I enjoy driving fast                                                                   3
# I enjoy rollercoasters                                                                 4
# Have you ever bungee-jumped?                                                           5
# I enjoy impulse shopping                                                               6
# I sometimes go out on weeknights even if I have work to do                             3
# I enjoy doing things without too much planning                                         3
# Have you ever been rock climbing?                                                      3
# I enjoy being in large loud crowds like the Times Square Ball Drop on New Years Eve    6
# I enjoy going to large music or dance festivals                                        3
# I enjoy watching horror movies                                                         5
# No risk - No fun                                                                       4
# I like to be surprised even if it startles or scares me                                3
# Have you ever parachuted?                                                              5
# I enjoy haunted houses                                                                 3
# I had a sheltered upbringing                                                           3
# My life is very stressful                                                              3
# I value my life to be well ordered and predictable                                     4
# Have you ridden a motorcycle?                                                          7
# Have you gambled or bet for money?                                                     4
# Have you ever been sky-diving?                                                         6
# dtype: int64

# %%
# fill all missing in each column in the table with their mode
for column in ss:
    print(column)
    ss[column].fillna(ss[column].median(), inplace = True)
# Out:
# I enjoy driving fast
# I enjoy rollercoasters
# Have you ever bungee-jumped?
# I enjoy impulse shopping
# I sometimes go out on weeknights even if I have work to do
# I enjoy doing things without too much planning
# Have you ever been rock climbing?
# I enjoy being in large loud crowds like the Times Square Ball Drop on New Years Eve
# I enjoy going to large music or dance festivals
# I enjoy watching horror movies
# No risk - No fun
# I like to be surprised even if it startles or scares me
# Have you ever parachuted?
# I enjoy haunted houses
# I had a sheltered upbringing
# My life is very stressful
# I value my life to be well ordered and predictable
# Have you ridden a motorcycle?
# Have you gambled or bet for money?
# Have you ever been sky-diving?

# %%
# check if there's still null values
ss.isnull().sum()
# Out:
# I enjoy driving fast                                                                   0
# I enjoy rollercoasters                                                                 0
# Have you ever bungee-jumped?                                                           0
# I enjoy impulse shopping                                                               0
# I sometimes go out on weeknights even if I have work to do                             0
# I enjoy doing things without too much planning                                         0
# Have you ever been rock climbing?                                                      0
# I enjoy being in large loud crowds like the Times Square Ball Drop on New Years Eve    0
# I enjoy going to large music or dance festivals                                        0
# I enjoy watching horror movies                                                         0
# No risk - No fun                                                                       0
# I like to be surprised even if it startles or scares me                                0
# Have you ever parachuted?                                                              0
# I enjoy haunted houses                                                                 0
# I had a sheltered upbringing                                                           0
# My life is very stressful                                                              0
# I value my life to be well ordered and predictable                                     0
# Have you ridden a motorcycle?                                                          0
# Have you gambled or bet for money?                                                     0
# Have you ever been sky-diving?                                                         0
# dtype: int64

# %%
ss
# Out:
#       I enjoy driving fast  I enjoy rollercoasters   \
# 0                      5.0                      5.0
# 1                      4.0                      5.0
# 2                      4.0                      4.0
# 3                      5.0                      5.0
# 4                      4.0                      1.0
# ...                    ...                      ...
# 1092                   2.0                      4.0
# 1093                   3.0                      5.0
# 1094                   4.0                      5.0
# 1095                   3.0                      4.0
# 1096                   5.0                      5.0
#
#       Have you ever bungee-jumped?  I enjoy impulse shopping  \
# 0                              2.0                       5.0
# 1                              2.0                       4.0
# 2                              1.0                       2.0
# 3                              2.0                       5.0
# 4                              3.0                       3.0
# ...                            ...                       ...
# 1092                           2.0                       5.0
# 1093                           2.0                       5.0
# 1094                           2.0                       2.0
# 1095                           2.0                       5.0
# 1096                           1.0                       5.0
#
#       I sometimes go out on weeknights even if I have work to do  \
# 0                                                   1.0
# 1                                                   2.0
# 2                                                   2.0
# 3                                                   4.0
# 4                                                   2.0
# ...                                                 ...
# 1092                                                2.0
# 1093                                                4.0
# 1094                                                3.0
# 1095                                                2.0
# 1096                                                4.0
#
#       I enjoy doing things without too much planning   \
# 0                                                 2.0
# 1                                                 1.0
# 2                                                 2.0
# 3                                                 2.0
# 4                                                 3.0
# ...                                               ...
# 1092                                              1.0
# 1093                                              1.0
# 1094                                              1.0
# 1095                                              5.0
# 1096                                              2.0
#
#       Have you ever been rock climbing?  \
# 0                                   3.0
# 1                                   1.0
# 2                                   1.0
# 3                                   4.0
# 4                                   3.0
# ...                                 ...
# 1092                                3.0
# 1093                                4.0
# 1094                                4.0
# 1095                                1.0
# 1096                                4.0
#
#       I enjoy being in large loud crowds like the Times Square Ball Drop on New Years Eve  \
# 0                                                   1.0
# 1                                                   2.0
# 2                                                   3.0
# 3                                                   4.0
# 4                                                   1.0
# ...                                                 ...
# 1092                                                2.0
# 1093                                                4.0
# 1094                                                1.0
# 1095                                                2.0
# 1096                                                2.0
#
#       I enjoy going to large music or dance festivals   \
# 0                                                  4.0
# 1                                                  4.0
# 2                                                  4.0
# 3                                                  5.0
# 4                                                  3.0
# ...                                                ...
# 1092                                               5.0
# 1093                                               5.0
# 1094                                               4.0
# 1095                                               1.0
# 1096                                               5.0
#
#       I enjoy watching horror movies  No risk - No fun  \
# 0                                1.0               3.0
# 1                                1.0               3.0
# 2                                1.0               3.0
# 3                                4.0               1.0
# 4                                1.0               4.0
# ...                              ...               ...
# 1092                             1.0               3.0
# 1093                             5.0               4.0
# 1094                             1.0               2.0
# 1095                             2.0               2.0
# 1096                             2.0               1.0
#
#       I like to be surprised even if it startles or scares me  \
# 0                                                   5.0
# 1                                                   4.0
# 2                                                   1.0
# 3                                                   4.0
# 4                                                   4.0
# ...                                                 ...
# 1092                                                3.0
# 1093                                                5.0
# 1094                                                2.0
# 1095                                                3.0
# 1096                                                2.0
#
#       Have you ever parachuted?  I enjoy haunted houses  \
# 0                           1.0                     1.0
# 1                           1.0                     1.0
# 2                           2.0                     1.0
# 3                           1.0                     4.0
# 4                           1.0                     2.0
# ...                         ...                     ...
# 1092                        2.0                     1.0
# 1093                        2.0                     1.0
# 1094                        2.0                     1.0
# 1095                        1.0                     1.0
# 1096                        1.0                     1.0
#
#       I had a sheltered upbringing  My life is very stressful  \
# 0                              1.0                        2.0
# 1                              4.0                        3.0
# 2                              3.0                        4.0
# 3                              4.0                        3.0
# 4                              3.0                        3.0
# ...                            ...                        ...
# 1092                           4.0                        4.0
# 1093                           5.0                        4.0
# 1094                           4.0                        4.0
# 1095                           4.0                        4.0
# 1096                           4.0                        5.0
#
#       I value my life to be well ordered and predictable  \
# 0                                                   3.0
# 1                                                   3.0
# 2                                                   4.0
# 3                                                   4.0
# 4                                                   1.0
# ...                                                 ...
# 1092                                                4.0
# 1093                                                5.0
# 1094                                                5.0
# 1095                                                3.0
# 1096                                                3.0
#
#       Have you ridden a motorcycle?  Have you gambled or bet for money?  \
# 0                               2.0                                 2.0
# 1                               4.0                                 1.0
# 2                               2.0                                 1.0
# 3                               1.0                                 1.0
# 4                               1.0                                 4.0
# ...                             ...                                 ...
# 1092                            1.0                                 1.0
# 1093                            3.0                                 1.0
# 1094                            2.0                                 3.0
# 1095                            1.0                                 4.0
# 1096                            2.0                                 3.0
#
#       Have you ever been sky-diving?
# 0                                1.0
# 1                                1.0
# 2                                2.0
# 3                                1.0
# 4                                3.0
# ...                              ...
# 1092                             2.0
# 1093                             2.0
# 1094                             2.0
# 1095                             1.0
# 1096                             1.0
#
# [1097 rows x 20 columns]

# %%
# sclae the sensation seeking data
min_max = preprocessing.MinMaxScaler()
table2 = min_max.fit_transform(ss.values)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.decomposition import PCA
# 3. Compute and visualize the correlation matrix

# The reason this matters is so you can evalute the output of the PCA.
# Nothing in the PCA will not already be foreshadowed by this. 
# If there are clusters in the data here, there will be factors in the PCA

# Compute correlation between each measure across all courses:
# True = variables are rowwise; False = variables are columnwise
corrMatrix = np.corrcoef(table2,rowvar=False) 

# Plot the data:
plt.imshow(corrMatrix) 
plt.xlabel('Question')
plt.ylabel('Question')
plt.colorbar()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.decomposition import PCA
# 3. Compute and visualize the correlation matrix

# The reason this matters is so you can evalute the output of the PCA.
# Nothing in the PCA will not already be foreshadowed by this. 
# If there are clusters in the data here, there will be factors in the PCA

# Compute correlation between each measure across all courses:
# True = variables are rowwise; False = variables are columnwise
corrMatrix = np.corrcoef(ss,rowvar=False) 

# Plot the data:
plt.imshow(corrMatrix) 
plt.xlabel('Question')
plt.ylabel('Question')
plt.colorbar()
plt.show()

# %%
# draw a heat map of correlations among variables
pd.DataFrame(table2).corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# /Users/beckybian/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   """Entry point for launching an IPython kernel.
# <style type="text/css">
# #T_f73c1_row0_col0, #T_f73c1_row1_col1, #T_f73c1_row2_col2, #T_f73c1_row3_col3, #T_f73c1_row4_col4, #T_f73c1_row5_col5, #T_f73c1_row6_col6, #T_f73c1_row7_col7, #T_f73c1_row8_col8, #T_f73c1_row9_col9, #T_f73c1_row10_col10, #T_f73c1_row11_col11, #T_f73c1_row12_col12, #T_f73c1_row13_col13, #T_f73c1_row14_col14, #T_f73c1_row15_col15, #T_f73c1_row16_col16, #T_f73c1_row17_col17, #T_f73c1_row18_col18, #T_f73c1_row19_col19 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f73c1_row0_col1 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_f73c1_row0_col2, #T_f73c1_row7_col4 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_f73c1_row0_col3, #T_f73c1_row5_col6, #T_f73c1_row7_col18, #T_f73c1_row18_col8, #T_f73c1_row18_col9 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_f73c1_row0_col4, #T_f73c1_row3_col1, #T_f73c1_row5_col17, #T_f73c1_row7_col14, #T_f73c1_row8_col18, #T_f73c1_row17_col0, #T_f73c1_row18_col6 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_f73c1_row0_col5, #T_f73c1_row3_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_f73c1_row0_col6, #T_f73c1_row2_col13, #T_f73c1_row4_col7, #T_f73c1_row7_col2, #T_f73c1_row8_col0, #T_f73c1_row9_col2, #T_f73c1_row18_col4 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_f73c1_row0_col7, #T_f73c1_row3_col14, #T_f73c1_row6_col7, #T_f73c1_row6_col9, #T_f73c1_row6_col15, #T_f73c1_row18_col2 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_f73c1_row0_col8, #T_f73c1_row1_col16, #T_f73c1_row2_col6, #T_f73c1_row10_col18 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_f73c1_row0_col9, #T_f73c1_row2_col4, #T_f73c1_row2_col8, #T_f73c1_row4_col2, #T_f73c1_row5_col18, #T_f73c1_row8_col2, #T_f73c1_row8_col15, #T_f73c1_row9_col0, #T_f73c1_row9_col15, #T_f73c1_row9_col18, #T_f73c1_row17_col8, #T_f73c1_row17_col18, #T_f73c1_row19_col9 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_f73c1_row0_col10 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_f73c1_row0_col11, #T_f73c1_row0_col19, #T_f73c1_row8_col11, #T_f73c1_row10_col13 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T
{
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_d5ace_row0_col9, #T_d5ace_row2_col4, #T_d5ace_row2_col8, #T_d5ace_row4_col2, #T_d5ace_row5_col18, #T_d5ace_row8_col2, #T_d5ace_row8_col15, #T_d5ace_row9_col0, #T_d5ace_row9_col15, #T_d5ace_row9_col18, #T_d5ace_row17_col8, #T_d5ace_row17_col18, #T_d5ace_row19_col9 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_d5ace_row0_col10 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_d5ace_row0_col11, #T_d5ace_row0_col19, #T_d5ace_row8_col11, #T_d5ace_row10_col13 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_d5ace_row0_col12, #T_d5ace_row10_col7, #T_d5ace_row11_col4, #T_d5ace_row18_col11, #T_d5ace_row18_col16 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_d5ace_row0_col13, #T_d5ace_row4_col12, #T_d5ace_row6_col18, #T_d5ace_row12_col0, #T_d5ace_row12_col13, #T_d5ace_row12_col17 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_d5ace_row0_col14, #T_d5ace_row9_col14, #T_d5ace_row16_col1, #T_d5ace_row17_col3 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_d5ace_row0_col15, #T_d5ace_row8_col6, #T_d5ace_row10_col16, #T_d5ace_row12_col9, #T_d5ace_row13_col15, #T_d5ace_row18_col13 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_d5ace_row0_col16, #T_d5ace_row4_col3, #T_d5ace_row8_col1, #T_d5ace_row17_col10, #T_d5ace_row17_col16, #T_d5ace_row19_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_d5ace_row0_col17, #T_d5ace_row4_col9, #T_d5ace_row8_col17, #T_d5ace_row15_col1, #T_d5ace_row18_col7 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_d5ace_row0_col18, #T_d5ace_row1_col6, #T_d5ace_row1_col8, #T_d5ace_row6_col16, #T_d5ace_row13_col2, #T_d5ace_row13_col16 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_d5ace_row1_col0, #T_d5ace_row1_col10, #T_d5ace_row3_col4, #T_d5ace_row6_col1, #T_d5ace_row6_col2, #T_d5ace_row9_col1, #T_d5ace_row10_col8 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_d5ace_row1_col2, #T_d5ace_row8_col5 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_d5ace_row1_col3, #T_d5ace_row2_col18, #T_d5ace_row4_col0, #T_d5ace_row4_col6, #T_d5ace_row4_col13, #T_d5ace_row4_col14, #T_d5ace_row5_col14, #T_d5ace_row15_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_d5ace_row1_col4, #T_d5ace_row3_col11, #T_d5ace_row7_col19, #T_d5ace_row16_col14 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_d5ace_row1_col5, #T_d5ace_row5_col4 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_d5ace_row1_col7, #T_d5ace_row3_col18, #T_d5ace_row4_col15, #T_d5ace_row18_col12, #T_d5ace_row18_col15, #T_d5ace_row19_col7 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_d5ace_row1_col9, #T_d5ace_row1_col13, #T_d5ace_row3_col16, #T_d5ace_row5_col8, #T_d5ace_row10_col4, #T_d5ace_row10_col9 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_d5ace_row1_col11 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_d5ace_row1_col12, #T_d5ace_row12_col1, #T_d5ace_row13_col10, #T_d5ace_row17_col5, #T_d5ace_row19_col5 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_d5ace_row1_col14, #T_d5ace_row14_col18 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_d5ace_row1_col15, #T_d5ace_row1_col18, #T_d5ace_row2_col7, #T_d5ace_row15_col8 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_d5ace_row1_col17, #T_d5ace_row2_col15, #T_d5ace_row3_col12, #T_d5ace_row11_col14 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_d5ace_row1_col19 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_d5ace_row2_col0 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_d5ace_row2_col1 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_d5ace_row2_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_d5ace_row2_col5, #T_d5ace_row5_col10 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_d5ace_row2_col9, #T_d5ace_row3_col0, #T_d5ace_row4_col1, #T_d5ace_row4_col19, #T_d5ace_row7_col1, #T_d5ace_row11_col16, #T_d5ace_row11_col18, #T_d5ace_row19_col4, #T_d5ace_row19_col17 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_d5ace_row2_col10, #T_d5ace_row5_col11, #T_d5ace_row6_col12, #T_d5ace_row13_col5 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_d5ace_row2_col11, #T_d5ace_row12_col10, #T_d5ace_row12_col11, #T_d5ace_row13_col1 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_d5ace_row2_col12, #T_d5ace_row11_col10 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_d5ace_row2_col14, #T_d5ace_row5_col15, #T_d5ace_row5_col16, #T_d5ace_row14_col0, #T_d5ace_row14_col1, #T_d5ace_row14_col2, #T_d5ace_row14_col9, #T_d5ace_row14_col13, #T_d5ace_row14_col19, #T_d5ace_row16_col4, #T_d5ace_row16_col5, #T_d5ace_row16_col6, #T_d5ace_row16_col7, #T_d5ace_row16_col8, #T_d5ace_row16_col10, #T_d5ace_row16_col11, #T_d5ace_row16_col12, #T_d5ace_row16_col17, #T_d5ace_row16_col18, #T_d5ace_row19_col3, #T_d5ace_row19_col14 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d5ace_row2_col16, #T_d5ace_row5_col1, #T_d5ace_row5_col19, #T_d5ace_row9_col8, #T_d5ace_row12_col16, #T_d5ace_row17_col2, #T_d5ace_row19_col13, #T_d5ace_row19_col16 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_d5ace_row2_col17, #T_d5ace_row10_col3, #T_d5ace_row11_col6, #T_d5ace_row11_col17, #T_d5ace_row13_col7, #T_d5ace_row15_col10, #T_d5ace_row17_col13 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_d5ace_row2_col19, #T_d5ace_row19_col2 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_d5ace_row3_col2, #T_d5ace_row6_col14, #T_d5ace_row9_col6 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_d5ace_row3_col6, #T_d5ace_row9_col3, #T_d5ace_row9_col7, #T_d5ace_row9_col17, #T_d5ace_row15_col17, #T_d5ace_row18_col3 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_d5ace_row3_col7, #T_d5ace_row4_col17, #T_d5ace_row7_col3, #T_d5ace_row7_col15, #T_d5ace_row7_col17, #T_d5ace_row10_col6, #T_d5ace_row17_col6 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_d5ace_row3_col8, #T_d5ace_row11_col12 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_d5ace_row3_col9, #T_d5ace_row7_col6, #T_d5ace_row7_col9, #T_d5ace_row8_col14, #T_d5ace_row10_col14, #T_d5ace_row15_col4 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_d5ace_row3_col10, #T_d5ace_row5_col12, #T_d5ace_row6_col0, #T_d5ace_row6_col11, #T_d5ace_row8_col3, #T_d5ace_row11_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_d5ace_row3_col13 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_d5ace_row3_col15, #T_d5ace_row7_col16, #T_d5ace_row9_col16, #T_d5ace_row13_col19 {
#   background-c

# %%
# conduct PCA in this table2
pca = PCA().fit(table2)

#% matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (12,6)

fig, ax = plt.subplots()
xi = np.arange(1, 21, step=1)
y = np.cumsum(pca.explained_variance_ratio_)

plt.ylim(0.0,1.1)
plt.plot(xi, y, marker='o', linestyle='--', color='b')

plt.xlabel('Number of Components')
plt.xticks(np.arange(0, 25, step=1)) #change from 0-based array index to 1-based human-readable label
plt.ylabel('Cumulative variance (%)')
plt.title('The number of components needed to explain variance')

plt.axhline(y=0.95, color='r', linestyle='-')
plt.text(0.5, 0.85, '95% cut-off threshold', color = 'red', fontsize=16)

ax.grid(axis='x')
plt.show()

# %%
# according to the plot, we determine to have 17 principal components

# %%
#95% of variance
from sklearn.decomposition import PCA
pca = PCA(n_components = 0.95)
pca.fit(table2)
reduced1 = pca.transform(table2)

# %%
col=[]
for i in range(17):
    col.append("SSPC"+str(i+1))

# %%
pca1=pd.DataFrame(reduced1,columns=col)

# %%
pca1
# Out:
#          SSPC1     SSPC2     SSPC3     SSPC4     SSPC5     SSPC6     SSPC7  \
# 0     0.220084  0.296276 -0.297516  0.315106 -0.379593  0.086728  0.416873
# 1     0.524533  0.140586 -0.197538 -0.203813  0.444126 -0.028452  0.787972
# 2     0.839987  0.112457 -0.247706 -0.112533 -0.016231  0.094788  0.732241
# 3    -0.356084 -0.141328 -0.329761 -0.485040 -0.593075 -0.658287 -0.071305
# 4     0.244832  0.353588  0.393065  0.573104 -0.242872  0.525889 -0.330908
# ...        ...       ...       ...       ...       ...       ...       ...
# 1092  0.626955  0.209000 -0.486692 -0.245621 -0.408901 -0.405730  0.241991
# 1093 -0.413606  0.092758 -0.406054 -0.511346  0.114153 -0.783144  0.142383
# 1094  0.453768  0.379044 -0.379374  0.735531 -0.180420 -0.444307  0.194894
# 1095  0.561848  0.132306  0.622902  0.274555 -0.493908  0.477496  0.113841
# 1096  0.233292  0.591051  0.084903  0.150102 -0.483396 -0.753071  0.168819
#
#          SSPC8     SSPC9    SSPC10    SSPC11    SSPC12    SSPC13    SSPC14  \
# 0     0.173147  0.093217  0.864752 -0.097978  0.087330 -0.272088 -0.324641
# 1    -0.100744 -0.465175  0.353217 -0.169872  0.028829 -0.197747 -0.179675
# 2    -0.448321 -0.028399  0.144640 -0.073098 -0.210404  0.116571  0.096237
# 3    -0.044502  0.045957 -0.020032 -0.158331 -0.193349  0.411126 -0.260260
# 4    -0.287168  0.060136  0.561544  0.615635  0.167436 -0.167983  0.332382
# ...        ...       ...       ...       ...       ...       ...       ...
# 1092 -0.152613 -0.063179  0.018896  0.303041  0.404876 -0.356610  0.146390
# 1093 -0.077949 -0.241339 -0.232372  0.306737  0.018965 -0.346005 -0.163683
# 1094 -0.216425 -0.178300 -0.264673 -0.006248 -0.314035 -0.127076  0.250498
# 1095  0.123325 -0.563852  0.175225 -0.157352  0.543604  0.037676 -0.290859
# 1096  0.271440 -0.158860  0.006703 -0.420281 -0.186412  0.016133  0.233719
#
#         SSPC15    SSPC16    SSPC17
# 0    -0.703273  0.005897  0.208855
# 1    -0.531328 -0.063227  0.369151
# 2     0.138088 -0.014963 -0.116142
# 3    -0.241085  0.002886  0.328621
# 4    -0.115129 -0.325293  0.237982
# ...        ...       ...       ...
# 1092 -0.308183 -0.041069 -0.010520
# 1093 -0.335434  0.731999  0.233943
# 1094 -0.164372  0.031872 -0.103334
# 1095  0.383944  0.192737 -0.011743
# 1096  0.020632  0.015607  0.393427
#
# [1097 rows x 17 columns]

# %%
# concact factor table after pca and movie (standardized)
sstable=pd.concat([mt,pca1],axis=1)

# %%
# converting to csv
sstable.to_csv('/Users/beckybian/Desktop/NYUstudy/大三下/Intro to DS/Final project/sstable.csv')

# %% [markdown]
# # Personality PCA

# %%
# conduct PCA for personality variables
ps=data.iloc[:,420:464]

# %%
ps
# Out:
#       Is talkative  Tends to find fault with others  Does a thorough job  \
# 0              1.0                              2.0                  NaN
# 1              2.0                              3.0                  4.0
# 2              4.0                              2.0                  4.0
# 3              5.0                              3.0                  5.0
# 4              4.0                              4.0                  4.0
# ...            ...                              ...                  ...
# 1092           4.0                              4.0                  4.0
# 1093           5.0                              5.0                  5.0
# 1094           4.0                              2.0                  5.0
# 1095           4.0                              2.0                  4.0
# 1096           5.0                              4.0                  5.0
#
#       Is depressed/Blue  Is original/comes up with new ideas  Is reserved  \
# 0                   4.0                                  4.0          5.0
# 1                   1.0                                  3.0          5.0
# 2                   2.0                                  3.0          3.0
# 3                   4.0                                  5.0          3.0
# 4                   4.0                                  2.0          3.0
# ...                 ...                                  ...          ...
# 1092                4.0                                  3.0          3.0
# 1093                2.0                                  5.0          4.0
# 1094                4.0                                  2.0          5.0
# 1095                3.0                                  5.0          5.0
# 1096                2.0                                  4.0          3.0
#
#       Is helpful and unselfish with others  Can be somewhat careless  \
# 0                                      2.0                       3.0
# 1                                      3.0                       4.0
# 2                                      4.0                       4.0
# 3                                      4.0                       1.0
# 4                                      4.0                       4.0
# ...                                    ...                       ...
# 1092                                   4.0                       4.0
# 1093                                   5.0                       5.0
# 1094                                   5.0                       1.0
# 1095                                   5.0                       5.0
# 1096                                   5.0                       4.0
#
#       Is relaxed/handles stress well  Is curious about many different things  \
# 0                                5.0                                     1.0
# 1                                3.0                                     3.0
# 2                                2.0                                     4.0
# 3                                2.0                                     5.0
# 4                                2.0                                     4.0
# ...                              ...                                     ...
# 1092                             2.0                                     5.0
# 1093                             5.0                                     4.0
# 1094                             2.0                                     5.0
# 1095                             4.0                                     4.0
# 1096                             5.0                                     5.0
#
#       ...  Prefers work that is routine  is outgoing/sociable  \
# 0     ...                           1.0                   1.0
# 1     ...                           4.0                   1.0
# 2     ...                           2.0                   3.0
# 3     ...                           3.0                   3.0
# 4     ...                           2.0                   4.0
# ...   ...                           ...                   ...
# 1092  ...                           4.0                   3.0
# 1093  ...                           4.0                   5.0
# 1094  ...                           4.0                   4.0
# 1095  ...                           3.0                   2.0
# 1096  ...                           1.0                   5.0
#
#       Is sometimes rude to others  Makes plans and follows through with them  \
# 0                             5.0                                        2.0
# 1                             3.0                                        4.0
# 2                             2.0                                        3.0
# 3                             2.0                                        3.0
# 4                             4.0                                        4.0
# ...                           ...                                        ...
# 1092                          2.0                                        5.0
# 1093                          4.0                                        4.0
# 1094                          4.0                                        5.0
# 1095                          2.0                                        3.0
# 1096                          2.0                                        4.0
#
#       Gets nervous easily  Likes to reflect/play with ideas  \
# 0                     4.0                               5.0
# 1                     2.0                               3.0
# 2                     4.0                               4.0
# 3                     4.0                               4.0
# 4                     4.0                               3.0
# ...                   ...                               ...
# 1092                  4.0                               4.0
# 1093                  5.0                               5.0
# 1094                  4.0                               5.0
# 1095                  5.0                               4.0
# 1096                  2.0                               4.0
#
#       Has few artistic interests  Likes to cooperate with others  \
# 0                            1.0                             4.0
# 1                            1.0                             3.0
# 2                            2.0                             5.0
# 3                            1.0                             4.0
# 4                            4.0                             4.0
# ...                          ...                             ...
# 1092                         2.0                             4.0
# 1093                         4.0                             5.0
# 1094                         1.0                             5.0
# 1095                         2.0                             4.0
# 1096                         2.0                             5.0
#
#       Is easily distracted  Is sophisticated in art or music or literature
# 0                      5.0                                             5.0
# 1                      2.0                                             3.0
# 2                      3.0                                             3.0
# 3                      4.0                                             4.0
# 4                      4.0                                             4.0
# ...                    ...                                             ...
# 1092                   3.0                                             4.0
# 1093                   5.0                                             4.0
# 1094                   1.0                                             5.0
# 1095                   4.0                                             5.0
# 1096                   3.0                                             5.0
#
# [1097 rows x 44 columns]

# %%
# fill all missing in each column in the table with their mode
for column in ps:
    print(column)
    ps[column].fillna(ps[column].median(), inplace = True)
# Out:
# Is talkative
# Tends to find fault with others
# Does a thorough job
# Is depressed/Blue
# Is original/comes up with new ideas
# Is reserved
# Is helpful and unselfish with others
# Can be somewhat careless
# Is relaxed/handles stress well
# Is curious about many different things
# Is full of energy
# Starts quarrels with others
# Is a reliable worker
# Can be tense
# Is ingenious/a deep thinker
# Generates a lot of Enthusiasm
# Has a forgiving nature
# Tends to be disorganized
# Worries a lot
# Has an active imagination
# Tends to be quiet
# Is generally trusting
# Tends to be lazy
# Is emotionally stable/not easily upset
# is inventive
# Has an assertive personality
# Can be cold and aloof
# Perseveres until the task is finished
# Can be moody
# Values artistic/aesthetic experiences
# Is sometimes shy/inhibited
# Is considerate and kind to almost everyone
# Does things efficiently
# Remains calm in tense situations
# Prefers work that is routine
# is outgoing/sociable
# Is sometimes rude to others
# Makes plans and follows through with them
# Gets nervous easily
# Likes to reflect/play with ideas
# Has few artistic interests
# Likes to cooperate with others
# Is easily distracted
# Is sophisticated in art or music or literature

# %%
# check if there's still missing values
ps.isnull().sum()
# Out:
# Is talkative                                      0
# Tends to find fault with others                   0
# Does a thorough job                               0
# Is depressed/Blue                                 0
# Is original/comes up with new ideas               0
# Is reserved                                       0
# Is helpful and unselfish with others              0
# Can be somewhat careless                          0
# Is relaxed/handles stress well                    0
# Is curious about many different things            0
# Is full of energy                                 0
# Starts quarrels with others                       0
# Is a reliable worker                              0
# Can be tense                                      0
# Is ingenious/a deep thinker                       0
# Generates a lot of Enthusiasm                     0
# Has a forgiving nature                            0
# Tends to be disorganized                          0
# Worries a lot                                     0
# Has an active imagination                         0
# Tends to be quiet                                 0
# Is generally trusting                             0
# Tends to be lazy                                  0
# Is emotionally stable/not easily upset            0
# is inventive                                      0
# Has an assertive personality                      0
# Can be cold and aloof                             0
# Perseveres until the task is finished             0
# Can be moody                                      0
# Values artistic/aesthetic experiences             0
# Is sometimes shy/inhibited                        0
# Is considerate and kind to almost everyone        0
# Does things efficiently                           0
# Remains calm in tense situations                  0
# Prefers work that is routine                      0
# is outgoing/sociable                              0
# Is sometimes rude to others                       0
# Makes plans and follows through with them         0
# Gets nervous easily                               0
# Likes to reflect/play with ideas                  0
# Has few artistic interests                        0
# Likes to cooperate with others                    0
# Is easily distracted                              0
# Is sophisticated in art or music or literature    0
# dtype: int64

# %%
# 1. Z-score the data:
#zscoredData = stats.zscore(data1)
min_max = preprocessing.MinMaxScaler()
table2 = min_max.fit_transform(ps.values)

# %%
# draw a heat map of correlations among variables
pd.DataFrame(table2).corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# /Users/beckybian/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   """Entry point for launching an IPython kernel.
# <style type="text/css">
# #T_0aead_row0_col0, #T_0aead_row1_col1, #T_0aead_row2_col2, #T_0aead_row3_col3, #T_0aead_row4_col4, #T_0aead_row5_col5, #T_0aead_row6_col6, #T_0aead_row7_col7, #T_0aead_row8_col8, #T_0aead_row9_col9, #T_0aead_row10_col10, #T_0aead_row11_col11, #T_0aead_row12_col12, #T_0aead_row13_col13, #T_0aead_row14_col14, #T_0aead_row15_col15, #T_0aead_row16_col16, #T_0aead_row17_col17, #T_0aead_row18_col18, #T_0aead_row19_col19, #T_0aead_row20_col20, #T_0aead_row21_col21, #T_0aead_row22_col22, #T_0aead_row23_col23, #T_0aead_row24_col24, #T_0aead_row25_col25, #T_0aead_row26_col26, #T_0aead_row27_col27, #T_0aead_row28_col28, #T_0aead_row29_col29, #T_0aead_row30_col30, #T_0aead_row31_col31, #T_0aead_row32_col32, #T_0aead_row33_col33, #T_0aead_row34_col34, #T_0aead_row35_col35, #T_0aead_row36_col36, #T_0aead_row37_col37, #T_0aead_row38_col38, #T_0aead_row39_col39, #T_0aead_row40_col40, #T_0aead_row41_col41, #T_0aead_row42_col42, #T_0aead_row43_col43 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_
col4 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_0aead_row0_col12, #T_0aead_row0_col27, #T_0aead_row2_col20, #T_0aead_row3_col7, #T_0aead_row3_col36, #T_0aead_row4_col27, #T_0aead_row8_col31, #T_0aead_row16_col29, #T_0aead_row17_col5, #T_0aead_row22_col1, #T_0aead_row23_col12, #T_0aead_row27_col29, #T_0aead_row31_col9, #T_0aead_row32_col18, #T_0aead_row34_col3, #T_0aead_row34_col27, #T_0aead_row37_col5, #T_0aead_row41_col37 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_0aead_row0_col13, #T_0aead_row7_col1, #T_0aead_row9_col20, #T_0aead_row9_col23, #T_0aead_row9_col41, #T_0aead_row11_col10, #T_0aead_row13_col22, #T_0aead_row14_col23, #T_0aead_row15_col43, #T_0aead_row19_col17, #T_0aead_row21_col2, #T_0aead_row21_col32, #T_0aead_row29_col16, #T_0aead_row30_col17, #T_0aead_row32_col24, #T_0aead_row34_col28, #T_0aead_row38_col17, #T_0aead_row43_col10, #T_0aead_row43_col33 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_0aead_row0_col14, #T_0aead_row11_col14, #T_0aead_row11_col21, #T_0aead_row31_col1, #T_0aead_row33_col42, #T_0aead_row38_col4, #T_0aead_row38_col24, #T_0aead_row41_col26, #T_0aead_row42_col2, #T_0aead_row42_col12 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_0aead_row0_col16, #T_0aead_row0_col32, #T_0aead_row3_col22, #T_0aead_row9_col25, #T_0aead_row10_col41, #T_0aead_row16_col20, #T_0aead_row17_col35, #T_0aead_row19_col8, #T_0aead_row21_col12, #T_0aead_row23_col2, #T_0aead_row23_col6, #T_0aead_row24_col20, #T_0aead_row31_col33, #T_0aead_row31_col37, #T_0aead_row33_col16, #T_0aead_row33_col31, #T_0aead_row34_col0, #T_0aead_row36_col17, #T_0aead_row38_col0, #T_0aead_row39_col12, #T_0aead_row39_col30,

# %%
# pca implemented here
pca = PCA().fit(table2)

#% matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (12,6)

fig, ax = plt.subplots()
xi = np.arange(1, 45, step=1)
y = np.cumsum(pca.explained_variance_ratio_)

plt.ylim(0.0,1.1)
plt.plot(xi, y, marker='o', linestyle='--', color='b')

plt.xlabel('Number of Components')
plt.xticks(np.arange(0, 50, step=1)) #change from 0-based array index to 1-based human-readable label
plt.ylabel('Cumulative variance (%)')
plt.title('The number of components needed to explain variance')

plt.axhline(y=0.95, color='r', linestyle='-')
plt.text(0.5, 0.85, '95% cut-off threshold', color = 'red', fontsize=16)

ax.grid(axis='x')
plt.show()

# %%
# according to the plot, we can extract 37 principal components

# %%
#95% of variance
from sklearn.decomposition import PCA
pca = PCA(n_components = 0.95)
pca.fit(table2)
reduced = pca.transform(table2)

# %%
col=[]
for i in range(37):
    col.append("PSPC"+str(i+1))

# %%
pca2=pd.DataFrame(reduced,columns=col)

# %%
pca2
# Out:
#          PSPC1     PSPC2     PSPC3     PSPC4     PSPC5     PSPC6     PSPC7  \
# 0     0.596214  0.591726  0.013713  0.017905  1.442316  0.406107  0.443075
# 1     0.504424  0.785285 -0.022495  0.361277  0.487984 -0.127045  0.645779
# 2     0.017027 -0.102422  0.066722  0.450091 -0.262518 -0.019252  0.078039
# 3    -0.258689 -0.375421 -0.846816  0.090217 -0.685316  0.418812  0.112838
# 4     0.533863 -0.490453  0.249229  0.173333 -0.313553 -0.018192 -0.063230
# ...        ...       ...       ...       ...       ...       ...       ...
# 1092  0.224860 -0.068833 -0.525328 -0.201254 -0.327880  0.116456  0.180668
# 1093 -0.286812 -0.807311 -0.150986  0.135690  0.844083 -1.280766  0.280594
# 1094 -0.362872  0.308766 -0.846310 -0.532285 -0.312495 -0.040677  0.420971
# 1095  0.013378 -0.232640 -0.942827  0.536562  0.403338 -0.296843  0.057348
# 1096 -1.219529 -0.404246 -0.304773 -0.261303  0.212423  0.267015  0.189920
#
#          PSPC8     PSPC9    PSPC10  ...    PSPC28    PSPC29    PSPC30  \
# 0    -0.520133  0.591504  0.618826  ... -0.058183 -0.222322  0.017678
# 1     0.019143 -0.489979 -0.004124  ... -0.225836  0.107379  0.086496
# 2     0.066048 -0.123071 -0.493720  ...  0.294059  0.007112 -0.050492
# 3     0.182796 -0.150410 -0.049586  ...  0.021273 -0.136544 -0.052639
# 4     0.098295  0.104848  0.177275  ...  0.128960  0.184088 -0.034257
# ...        ...       ...       ...  ...       ...       ...       ...
# 1092 -0.194652 -0.293357 -0.066943  ... -0.041143 -0.018045  0.190980
# 1093  0.129190  0.162551  0.038699  ... -0.145196  0.212738 -0.028558
# 1094 -0.401077  0.352735 -0.180718  ...  0.695803  0.370167  0.113143
# 1095 -0.073444 -0.235505  0.589440  ... -0.296757 -0.160183  0.066808
# 1096 -0.056347 -0.070224  0.603382  ...  0.076300 -0.097494  0.276860
#
#         PSPC31    PSPC32    PSPC33    PSPC34    PSPC35    PSPC36    PSPC37
# 0    -0.070782  0.321849 -0.439209 -0.132772 -0.112611 -0.082738  0.394967
# 1     0.197360  0.341486 -0.228804 -0.013300 -0.016856 -0.021500  0.330411
# 2    -0.027881 -0.014629  0.136865  0.016402  0.131223 -0.042024  0.233632
# 3    -0.071920 -0.042741 -0.136357 -0.118120 -0.002825  0.136169 -0.016188
# 4    -0.116285  0.054310  0.072814  0.155009 -0.008760 -0.047179 -0.160376
# ...        ...       ...       ...       ...       ...       ...       ...
# 1092 -0.114213  0.010384 -0.186765  0.233253 -0.113552 -0.018655 -0.284294
# 1093 -0.070636  0.195364  0.028353  0.109016 -0.033119 -0.160640 -0.137263
# 1094  0.005254  0.080996 -0.019961 -0.132251 -0.206145 -0.192249 -0.032305
# 1095 -0.207616  0.062654 -0.055001  0.196790  0.034182 -0.050404 -0.016269
# 1096  0.150219 -0.084721  0.296108 -0.122575 -0.076235  0.270013 -0.047214
#
# [1097 rows x 37 columns]

# %%
pstable=pd.concat([mt,pca2],axis=1)

# %%
# converting to csv
pstable.to_csv('/Users/beckybian/Desktop/NYUstudy/大三下/Intro to DS/Final project/pstable.csv')

# %%
pstable.isnull().sum()
# Out:
# The Life of David Gale (2003)                1021
# Wing Commander (1999)                        1026
# Django Unchained (2012)                       644
# Alien (1979)                                  808
# Indiana Jones and the Last Crusade (1989)     634
#                                              ...
# PC33                                            0
# PC34                                            0
# PC35                                            0
# PC36                                            0
# PC37                                            0
# Length: 437, dtype: int64

# %% [markdown]
# # movie experience

# %%
# conduct pca for move experience variables
me=data.iloc[:,464:474]

# %%
me
# Out:
#       I have cried during a movie  \
# 0                             3.0
# 1                             5.0
# 2                             4.0
# 3                             4.0
# 4                             4.0
# ...                           ...
# 1092                          5.0
# 1093                          5.0
# 1094                          4.0
# 1095                          5.0
# 1096                          5.0
#
#       I have trouble following the story of a movie  \
# 0                                               4.0
# 1                                               3.0
# 2                                               3.0
# 3                                               1.0
# 4                                               3.0
# ...                                             ...
# 1092                                            4.0
# 1093                                            4.0
# 1094                                            2.0
# 1095                                            5.0
# 1096                                            3.0
#
#       I have trouble remembering the story of a movie a couple of days after seeing it  \
# 0                                                   1.0
# 1                                                   1.0
# 2                                                   1.0
# 3                                                   1.0
# 4                                                   4.0
# ...                                                 ...
# 1092                                                3.0
# 1093                                                5.0
# 1094                                                3.0
# 1095                                                3.0
# 1096                                                4.0
#
#       When watching a movie I cheer or shout or talk or curse at the screen  \
# 0                                                   1.0
# 1                                                   3.0
# 2                                                   5.0
# 3                                                   3.0
# 4                                                   2.0
# ...                                                 ...
# 1092                                                3.0
# 1093                                                5.0
# 1094                                                6.0
# 1095                                                1.0
# 1096                                                3.0
#
#       When watching a movie I feel like the things on the screen are happening to me  \
# 0                                                   6.0
# 1                                                   1.0
# 2                                                   4.0
# 3                                                   1.0
# 4                                                   3.0
# ...                                                 ...
# 1092                                                4.0
# 1093                                                3.0
# 1094                                                3.0
# 1095                                                1.0
# 1096                                                4.0
#
#       As a movie unfolds I start to have problems keeping track of events that happened earlier  \
# 0                                                   2.0
# 1                                                   1.0
# 2                                                   3.0
# 3                                                   1.0
# 4                                                   2.0
# ...                                                 ...
# 1092                                                3.0
# 1093                                                5.0
# 1094                                                1.0
# 1095                                                1.0
# 1096                                                1.0
#
#       The emotions on the screen "rub off" on me - for instance if something sad is happening I get sad or if something frightening is happening I get scared  \
# 0                                                   5.0
# 1                                                   6.0
# 2                                                   5.0
# 3                                                   4.0
# 4                                                   5.0
# ...                                                 ...
# 1092                                                5.0
# 1093                                                5.0
# 1094                                                6.0
# 1095                                                4.0
# 1096                                                4.0
#
#       When watching a movie I get completely immersed in the alternative reality of the film  \
# 0                                                   5.0
# 1                                                   5.0
# 2                                                   5.0
# 3                                                   5.0
# 4                                                   6.0
# ...                                                 ...
# 1092                                                5.0
# 1093                                                5.0
# 1094                                                6.0
# 1095                                                3.0
# 1096                                                4.0
#
#       Movies change my position on social economic or political issues  \
# 0                                                   5.0
# 1                                                   3.0
# 2                                                   4.0
# 3                                                   3.0
# 4                                                   4.0
# ...                                                 ...
# 1092                                                4.0
# 1093                                                6.0
# 1094                                                4.0
# 1095                                                3.0
# 1096                                                4.0
#
#       When watching movies things get so intense that I have to stop watching
# 0                                                   1.0
# 1                                                   2.0
# 2                                                   4.0
# 3                                                   1.0
# 4                                                   4.0
# ...                                                 ...
# 1092                                                4.0
# 1093                                                5.0
# 1094                                                2.0
# 1095                                                1.0
# 1096                                                1.0
#
# [1097 rows x 10 columns]

# %%
# fill all missing in each column in the table with their mode
for column in me:
    print(column)
    me[column].fillna(me[column].median(), inplace = True)
# Out:
# I have cried during a movie
# I have trouble following the story of a movie
# I have trouble remembering the story of a movie a couple of days after seeing it
# When watching a movie I cheer or shout or talk or curse at the screen
# When watching a movie I feel like the things on the screen are happening to me
# As a movie unfolds I start to have problems keeping track of events that happened earlier
# The emotions on the screen "rub off" on me - for instance if something sad is happening I get sad or if something frightening is happening I get scared
# When watching a movie I get completely immersed in the alternative reality of the film
# Movies change my position on social economic or political issues
# When watching movies things get so intense that I have to stop watching

# %%
# check if there's missing values left
me.isnull().sum()
# Out:
# I have cried during a movie                                                                                                                                0
# I have trouble following the story of a movie                                                                                                              0
# I have trouble remembering the story of a movie a couple of days after seeing it                                                                           0
# When watching a movie I cheer or shout or talk or curse at the screen                                                                                      0
# When watching a movie I feel like the things on the screen are happening to me                                                                             0
# As a movie unfolds I start to have problems keeping track of events that happened earlier                                                                  0
# The emotions on the screen "rub off" on me - for instance if something sad is happening I get sad or if something frightening is happening I get scared    0
# When watching a movie I get completely immersed in the alternative reality of the film                                                                     0
# Movies change my position on social economic or political issues                                                                                           0
# When watching movies things get so intense that I have to stop watching                                                                                    0
# dtype: int64

# %%
# 1. Z-score the data:
#zscoredData = stats.zscore(data1)
min_max = preprocessing.MinMaxScaler()
table2 = min_max.fit_transform(me.values)

# %%
# draw a heat map containing correlations among those variables
pd.DataFrame(table2).corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# /Users/beckybian/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   """Entry point for launching an IPython kernel.
# <style type="text/css">
# #T_84a09_row0_col0, #T_84a09_row1_col1, #T_84a09_row2_col2, #T_84a09_row3_col3, #T_84a09_row4_col4, #T_84a09_row5_col5, #T_84a09_row6_col6, #T_84a09_row7_col7, #T_84a09_row8_col8, #T_84a09_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_84a09_row0_col1, #T_84a09_row3_col9 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_84a09_row0_col2 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_84a09_row0_col3 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_84a09_row0_col4, #T_84a09_row6_col8, #T_84a09_row9_col7 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_84a09_row0_col5, #T_84a09_row1_col4, #T_84a09_row1_col7, #T_84a09_row1_col8, #T_84a09_row2_col0, #T_84a09_row2_col3, #T_84a09_row2_col6, #T_84a09_row2_col7, #T_84a09_row2_col9, #T_84a09_row7_col1, #T_84a09_row7_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_84a09_row0_col6, #T_84a09_row4_col6 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_84a09_row0_col7 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_84a09_row0_col8, #T_84a09_row6_col3, #T_84a09_row6_col5, #T_84a09_row8_col1, #T_84a09_row8_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_84a09_row0_col9 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_84a09_row1_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_84a09_row1_col2 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_84a09_row1_col3, #T_84a09_row5_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T
step=1)) #change from 0-based array index to 1-based human-readable label
plt.ylabel('Cumulative variance (%)')
plt.title('The number of components needed to explain variance')

plt.axhline(y=0.95, color='r', linestyle='-')
plt.text(0.5, 0.85, '95% cut-off threshold', color = 'red', fontsize=16)

ax.grid(axis='x')
plt.show()

# %%
# According to the plot, we can determine that 9 principle components can be extracted

# %%
#95% of variance
from sklearn.decomposition import PCA
pca = PCA(n_components = 0.95)
pca.fit(table2)
reduced = pca.transform(table2)

# %%
# 1. Z-score the data:
# zscoredData = stats.zscore(data1)

# 2. Initialize PCA object and fit to our data:
pca = PCA().fit(table2)

# 3a. Eigenvalues: Single vector of eigenvalues in decreasing order of magnitude
eigVals = pca.explained_variance_

# 3b. Loadings (eigenvectors): Weights per factor in terms of the original data. Where do the
# principal components point, in terms of the 17 questions?
loadings = pca.components_

# 3c. Rotated Data: Simply the transformed data - we had 40 courses (rows) in
# terms of 17 variables (columns), now we have 40 courses in terms of 17
# factors ordered by decreasing eigenvalue
rotatedData = pca.fit_transform(table2)

# 4. For the purposes of this, you can think of eigenvalues in terms of 
# (co)variance explained:
covarExplained = eigVals/sum(eigVals)*100

numClasses = 10
x = np.linspace(1,numClasses,numClasses)
# 7. Interpreting the factors 
# Now that we realize that 1, 2 or 3 are reasonable solutions to the course
# evaluation issue, we have to interpret the factors.
# This is perhaps where researchers have the most leeway.
# You do this - in principle - by looking at the loadings.
# In which direction does the factor point? 

whichPrincipalComponent = 4 # Select and look at once factor at a time 
plt.bar(x,loadings[whichPrincipalComponent,:]*-1) # note: eigVecs multiplied by -1
plt.xlabel('Question')
plt.ylabel('Loading')
plt.show() # Show bar plot
#print(questions.values) # Display questions

# %%
col=[]
for i in range(9):
    col.append("MEPC"+str(i+1))

# %%
pca3=pd.DataFrame(reduced,columns=col)

# %%
pca3
# Out:
#          MEPC1     MEPC2     MEPC3     MEPC4     MEPC5     MEPC6     MEPC7  \
# 0     0.178037 -0.316151 -0.426295  0.392497  0.331581  0.072136  0.153122
# 1    -0.074203 -0.345129  0.062358 -0.439205 -0.242691  0.168613 -0.282411
# 2     0.503403 -0.129256  0.292794  0.182504 -0.243956 -0.133410 -0.171795
# 3    -0.407080 -0.427241  0.209593 -0.127626 -0.125694  0.254562 -0.159742
# 4     0.290585  0.040029 -0.336002  0.009269 -0.224962  0.010717 -0.129785
# ...        ...       ...       ...       ...       ...       ...       ...
# 1092  0.498500  0.118646 -0.142402 -0.057518 -0.173450 -0.147877  0.027002
# 1093  0.896731  0.614952  0.018536  0.042141 -0.482966  0.168338  0.060873
# 1094  0.441089 -0.263263  0.450902 -0.039125 -0.014925  0.355109 -0.250152
# 1095 -0.460227  0.209366 -0.201061 -0.485107 -0.077936  0.139093  0.176999
# 1096  0.069951 -0.007827  0.051289 -0.104580  0.199342  0.161011  0.384730
#
#          MEPC8     MEPC9
# 0     0.401321  0.152559
# 1     0.131249  0.087261
# 2     0.238806 -0.057880
# 3    -0.016352 -0.183383
# 4    -0.313647 -0.086822
# ...        ...       ...
# 1092  0.054098 -0.055103
# 1093 -0.059927 -0.133795
# 1094 -0.274555  0.094609
# 1095  0.121008  0.150695
# 1096 -0.195850  0.068061
#
# [1097 rows x 9 columns]

# %%
metable=pd.concat([mt,pca3],axis=1)

# %%
# converting to csv
metable.to_csv('/Users/beckybian/Desktop/NYUstudy/大三下/Intro to DS/Final project/metable.csv')

# %% [raw]
# We have conducted PCA for three groups of variables and generated three datasets after processing
